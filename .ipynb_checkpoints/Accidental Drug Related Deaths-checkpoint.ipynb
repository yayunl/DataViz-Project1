# %%
import pandas as pd
pd.set_option('display.max_colwidth', 1000)

# %%
death_data_df = pd.read_csv("Resources/Accidental_Drug_Related_Deaths_2012-2017.csv")
death_data_df.head()
# Out:
#   CaseNumber        Date  Year   Sex   Race   Age Residence City  \
# 0    14-9876   6/28/2014  2014   NaN    NaN   NaN            NaN
# 1   12-16897  11/30/2012  2012  Male  White  45.0            NaN
# 2   13-11849   8/12/2013  2013  Male  White  30.0      NEW HAVEN
# 3   14-17578  11/23/2014  2014  Male  White  27.0      NAUGATUCK
# 4   12-11497   8/14/2012  2012  Male  White  21.0        ENFIELD
#
#   Residence State Residence County   Death City     ...      Tramad  \
# 0             NaN              NaN          NaN     ...         NaN
# 1             NaN              NaN    NEW HAVEN     ...         NaN
# 2             NaN              NaN    NEW HAVEN     ...         NaN
# 3             NaN              NaN  NEW MILFORD     ...         NaN
# 4             NaN              NaN      ENFIELD     ...         NaN
#
#   Morphine (not heroin) Other Any Opioid MannerofDeath AmendedMannerofDeath  \
# 0                   NaN   NaN        NaN      Accident                  NaN
# 1                   NaN   NaN        NaN      Accident                  NaN
# 2                   NaN   NaN        NaN      Accident                  NaN
# 3                   NaN   NaN        NaN      Accident                  NaN
# 4                   NaN   NaN        NaN      Accident                  NaN
#
#                                    DeathLoc DeathLocationCity DeathLocLat  \
# 0               CT\n(41.544654, -72.651713)    CT\n(41.544654    41.54465
# 1    NEW HAVEN, CT\n(41.308252, -72.924161)         NEW HAVEN    41.30825
# 2    NEW HAVEN, CT\n(41.308252, -72.924161)         NEW HAVEN    41.30825
# 3  NEW MILFORD, CT\n(41.576633, -73.408713)       NEW MILFORD    41.57663
# 4      ENFIELD, CT\n(41.976501, -72.591985)           ENFIELD    41.97650
#
#   DeathLocLong
# 0    72.651713
# 1    72.924161
# 2    72.924161
# 3    73.408713
# 4    72.591985
#
# [5 rows x 36 columns]

# %%
pop_ed_data_df = pd.read_csv("Resources/2016_Educational_Attainment_Connecticut.csv", dtype=str)
pop_ed_data_df = pop_ed_data_df[pop_ed_data_df["Subject"].str.contains("Total; Estimate; Population ")]
# pop_ed_data_df = pop_ed_data_df.drop([5, 6, 7, 8, 9, 10, 11, 12], axis=0)
pop_ed_data_df.reset_index(drop=True)
# Out:
#              Code  \
# 0   HC01_EST_VC02
# 1   HC01_EST_VC03
# 2   HC01_EST_VC04
# 3   HC01_EST_VC05
# 4   HC01_EST_VC06
# 5   HC01_EST_VC08
# 6   HC01_EST_VC09
# 7   HC01_EST_VC10
# 8   HC01_EST_VC11
# 9   HC01_EST_VC12
# 10  HC01_EST_VC13
# 11  HC01_EST_VC14
# 12  HC01_EST_VC15
# 13  HC01_EST_VC20
# 14  HC01_EST_VC21
# 15  HC01_EST_VC22
# 16  HC01_EST_VC24
# 17  HC01_EST_VC25
# 18  HC01_EST_VC26
# 19  HC01_EST_VC28
# 20  HC01_EST_VC29
# 21  HC01_EST_VC30
# 22  HC01_EST_VC32
# 23  HC01_EST_VC33
# 24  HC01_EST_VC34
#
#                                                                                         Subject  \
# 0                                                    Total; Estimate; Population 18 to 24 years
# 1                   Total; Estimate; Population 18 to 24 years - Less than high school graduate
# 2      Total; Estimate; Population 18 to 24 years - High school graduate (includes equivalency)
# 3               Total; Estimate; Population 18 to 24 years - Some college or associate's degree
# 4                      Total; Estimate; Population 18 to 24 years - Bachelor's degree or higher
# 5                                                 Total; Estimate; Population 25 years and over
# 6                           Total; Estimate; Population 25 years and over - Less than 9th grade
# 7                 Total; Estimate; Population 25 years and over - 9th to 12th grade, no diploma
# 8   Total; Estimate; Population 25 years and over - High school graduate (includes equivalency)
# 9                       Total; Estimate; Population 25 years and over - Some college, no degree
# 10                           Total; Estimate; Population 25 years and over - Associate's degree
# 11                            Total; Estimate; Population 25 years and over - Bachelor's degree
# 12              Total; Estimate; Population 25 years and over - Graduate or professional degree
# 13                                                   Total; Estimate; Population 25 to 34 years
# 14                  Total; Estimate; Population 25 to 34 years - High school graduate or higher
# 15                     Total; Estimate; Population 25 to 34 years - Bachelor's degree or higher
# 16                                                   Total; Estimate; Population 35 to 44 years
# 17                  Total; Estimate; Population 35 to 44 years - High school graduate or higher
# 18                     Total; Estimate; Population 35 to 44 years - Bachelor's degree or higher
# 19                                                   Total; Estimate; Population 45 to 64 years
# 20                  Total; Estimate; Population 45 to 64 years - High school graduate or higher
# 21                     Total; Estimate; Population 45 to 64 years - Bachelor's degree or higher
# 22                                                Total; Estimate; Population 65 years and over
# 23               Total; Estimate; Population 65 years and over - High school graduate or higher
# 24                  Total; Estimate; Population 65 years and over - Bachelor's degree or higher
#
#       Value
# 0    356553
# 1     33601
# 2    105267
# 3    162400
# 4     55285
# 5   2467737
# 6    100513
# 7    133422
# 8    678776
# 9    415150
# 10   186288
# 11   541369
# 12   412219
# 13   436596
# 14   407069
# 15   189635
# 16   424492
# 17   388658
# 18   186794
# 19  1030009
# 20   949096
# 21   396021
# 22   576640
# 23   488979
# 24   181138

# %%
population_data_df = pop_ed_data_df.iloc[[0,5,8,11,14]]
population_data_df
