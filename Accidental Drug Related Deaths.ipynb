# %%
import pandas as pd
pd.set_option('display.max_colwidth', 1000)

# %%
death_data_df = pd.read_csv("Resources/Accidental_Drug_Related_Deaths_2012-2017.csv")
death_data_df.head()
# Out:
#   CaseNumber        Date  Year   Sex   Race   Age Residence City  \
# 0    14-9876   6/28/2014  2014   NaN    NaN   NaN            NaN
# 1   12-16897  11/30/2012  2012  Male  White  45.0            NaN
# 2   13-11849   8/12/2013  2013  Male  White  30.0      NEW HAVEN
# 3   14-17578  11/23/2014  2014  Male  White  27.0      NAUGATUCK
# 4   12-11497   8/14/2012  2012  Male  White  21.0        ENFIELD
#
#   Residence State Residence County   Death City     ...      Tramad  \
# 0             NaN              NaN          NaN     ...         NaN
# 1             NaN              NaN    NEW HAVEN     ...         NaN
# 2             NaN              NaN    NEW HAVEN     ...         NaN
# 3             NaN              NaN  NEW MILFORD     ...         NaN
# 4             NaN              NaN      ENFIELD     ...         NaN
#
#   Morphine (not heroin) Other Any Opioid MannerofDeath AmendedMannerofDeath  \
# 0                   NaN   NaN        NaN      Accident                  NaN
# ...

# %%
pop_ed_data_df = pd.read_csv("Resources/2016_Educational_Attainment_Connecticut.csv", dtype=str)
pop_ed_data_df = pop_ed_data_df[pop_ed_data_df["Subject"].str.contains("Total; Estimate; Population ")]
pop_ed_data_df = pop_ed_data_df.drop([60, 72, 84, 96, 108, 120, 132, 144])
pop_ed_data_df.reset_index(drop=True)
pop_ed_data_df
# Out:
#               Code  \
# 0    HC01_EST_VC02
# 12   HC01_EST_VC03
# 24   HC01_EST_VC04
# 36   HC01_EST_VC05
# 48   HC01_EST_VC06
# 180  HC01_EST_VC20
# 192  HC01_EST_VC21
# 204  HC01_EST_VC22
# 216  HC01_EST_VC24
# 228  HC01_EST_VC25
# 240  HC01_EST_VC26
# 252  HC01_EST_VC28
# 264  HC01_EST_VC29
# 276  HC01_EST_VC30
# 288  HC01_EST_VC32
# 300  HC01_EST_VC33
# 312  HC01_EST_VC34
#
#                                                                                       Subject  \
# 0                                                  Total; Estimate; Population 18 to 24 years
# 12                Total; Estimate; Population 18 to 24 years - Less than high school graduate
# 24   Total; Estimate; Population 18 to 24 years - High school graduate (includes equivalency)
# 36            Total; Estimate; Population 18 to 24 years - Some college or associate's degree
# 48                   Total; Estimate; Population 18 to 24 years - Bachelor's degree or higher
# ...

# %%
population_data_df = pop_ed_data_df.iloc[[0,5,8,11,14]]
population_data_df
# Out:
#               Code                                        Subject    Value
# 0    HC01_EST_VC02     Total; Estimate; Population 18 to 24 years   356553
# 180  HC01_EST_VC20     Total; Estimate; Population 25 to 34 years   436596
# 216  HC01_EST_VC24     Total; Estimate; Population 35 to 44 years   424492
# 252  HC01_EST_VC28     Total; Estimate; Population 45 to 64 years  1030009
# 288  HC01_EST_VC32  Total; Estimate; Population 65 years and over   576640
