# %%
# Dependencies# Depen 
import requests
import json
import pandas as pd
# Google developer API key
from config import gkey
import numpy as np

# %% [markdown]
# ### Fill out the empty county cells

# %%
# Import the raw data
drug_death_raw_df = pd.read_csv("Resources/Accidental_Drug_Related_Deaths_2012-2017.csv")
drug_death_raw_df = drug_death_raw_df[1:]
drug_death_raw_df.columns
# Out:
# Index(['CaseNumber', 'Date', 'Year', 'Sex', 'Race', 'Age', 'Residence City',
#        'Residence State', 'Residence County', 'Death City', 'Death State',
#        'Death County', 'Location', 'DescriptionofInjury', 'InjuryPlace',
#        'ImmediateCauseA', 'Heroin', 'Cocaine', 'Fentanyl', 'Oxycodone',
#        'Oxymorphone', 'EtOH', 'Hydrocodone', 'Benzodiazepine', 'Methadone',
#        'Amphet', 'Tramad', 'Morphine (not heroin)', 'Other', 'Any Opioid',
#        'MannerofDeath', 'AmendedMannerofDeath', 'DeathLoc',
#        'DeathLocationCity', 'DeathLocLat', 'DeathLocLong'],
#       dtype='object')

# %%
# index = 0
for rindex, row in drug_death_raw_df.iterrows():
    death_county = row['Death County']
#     print(death_county)
#     print(type(death_county))
#     index+=1
#     if index==3:
#         break
    if pd.isnull(death_county):
        
        # Use Google geo-api to populate the empty county
        death_city = row['DeathLocationCity']

#         print("Empty!")
        
        # Target city
        target_city = f"{death_city}, CT"

        # Build the endpoint URL
        target_url = "https://maps.googleapis.com/maps/api/geocode/json?" \
            "address=%s&key=%s" % (target_city, gkey)

        # Print the assembled URL, avoid pushing this print out to github for key security
        print(target_url)

        try:
            geo_data = requests.get(target_url).json()

            # Print the json
            county_name = ' '.join(geo_data["results"][0]["address_components"][1]['long_name'].split(' ')[:2])
            print(f"Empty county found at {rindex}. City:{target_city}, County:{county_name}")
#             print(county_name)

            # Populate the death county cell
            drug_death_raw_df.loc[rindex,'Death County'] = county_name
            
        except:
            print("Failed.")
# Out:
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2. City:NEW HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=WILLIMANTIC, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 11. City:WILLIMANTIC, CT, County:Windham
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 56. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=NORWALK, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 63. City:NORWALK, CT, County:Huntington
# https://maps.googleapis.com/maps/api/geocode/json?address=TOLLAND, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 77. City:TOLLAND, CT, County:Tolland County
# https://maps.googleapis.com/maps/api/geocode/json?address=STAFFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 82. City:STAFFORD, CT, County:Tolland County
# https://maps.googleapis.com/maps/api/geocode/json?address=WATERBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 113. City:WATERBURY, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW LONDON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 135. City:NEW LONDON, CT, County:New London
# https://maps.googleapis.com/maps/api/geocode/json?address=PLAINFIELD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 147. City:PLAINFIELD, CT, County:Windham County
# https://maps.googleapis.com/maps/api/geocode/json?address=AVON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 152. City:AVON, CT, County:Simsbury
# https://maps.googleapis.com/maps/api/geocode/json?address=STRATFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 155. City:STRATFORD, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=STAFFORD SPRINGS, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 158. City:STAFFORD SPRINGS, CT, County:Tolland County
# https://maps.googleapis.com/maps/api/geocode/json?address=ELLINGTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 167. City:ELLINGTON, CT, County:Tolland County
# https://maps.googleapis.com/maps/api/geocode/json?address=WINSTED, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 174. City:WINSTED, CT, County:Winchester
# https://maps.googleapis.com/maps/api/geocode/json?address=MONTVILLE, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 175. City:MONTVILLE, CT, County:Waterford
# https://maps.googleapis.com/maps/api/geocode/json?address=NORWALK, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 187. City:NORWALK, CT, County:Huntington
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 194. City:NEW HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 206. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=MILFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 232. City:MILFORD, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=EAST WINDSOR, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 241. City:EAST WINDSOR, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW MILFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 281. City:NEW MILFORD, CT, County:Litchfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=VERNON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 288. City:VERNON, CT, County:Manchester
# https://maps.googleapis.com/maps/api/geocode/json?address=NORWALK, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 307. City:NORWALK, CT, County:Huntington
# https://maps.googleapis.com/maps/api/geocode/json?address=TORRINGTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 336. City:TORRINGTON, CT, County:Litchfield
# https://maps.googleapis.com/maps/api/geocode/json?address=PLAINVILLE, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 345. City:PLAINVILLE, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 350. City:NEW HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=NORWICH, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 368. City:NORWICH, CT, County:New London
# https://maps.googleapis.com/maps/api/geocode/json?address=MIDDLETOWN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 377. City:MIDDLETOWN, CT, County:Middlesex County
# https://maps.googleapis.com/maps/api/geocode/json?address=PLAINFIELD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 397. City:PLAINFIELD, CT, County:Windham County
# https://maps.googleapis.com/maps/api/geocode/json?address=NORWICH, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 407. City:NORWICH, CT, County:New London
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW BRITAIN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 427. City:NEW BRITAIN, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=PLAINFIELD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 428. City:PLAINFIELD, CT, County:Windham County
# https://maps.googleapis.com/maps/api/geocode/json?address=TORRINGTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 429. City:TORRINGTON, CT, County:Litchfield
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 437. City:NEW HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=COVENTRY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 448. City:COVENTRY, CT, County:Tolland County
# https://maps.googleapis.com/maps/api/geocode/json?address=TORRINGTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 459. City:TORRINGTON, CT, County:Litchfield
# https://maps.googleapis.com/maps/api/geocode/json?address=MIDDLETOWN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 460. City:MIDDLETOWN, CT, County:Middlesex County
# https://maps.googleapis.com/maps/api/geocode/json?address=ROCKY HILL, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 475. City:ROCKY HILL, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=DANBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 496. City:DANBURY, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=SEYMOUR, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 497. City:SEYMOUR, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 512. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW LONDON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 532. City:NEW LONDON, CT, County:New London
# https://maps.googleapis.com/maps/api/geocode/json?address=PUTNAM, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 533. City:PUTNAM, CT, County:Windham County
# https://maps.googleapis.com/maps/api/geocode/json?address=TRUMBULL, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 556. City:TRUMBULL, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=RIDGEFIELD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 580. City:RIDGEFIELD, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=TORRINGTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 586. City:TORRINGTON, CT, County:Litchfield
# https://maps.googleapis.com/maps/api/geocode/json?address=MERIDEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 596. City:MERIDEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 597. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=DANBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 603. City:DANBURY, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW BRITAIN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 607. City:NEW BRITAIN, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=EAST HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 624. City:EAST HARTFORD, CT, County:Manchester
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 629. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=WATERBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 636. City:WATERBURY, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=GLASTONBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 637. City:GLASTONBURY, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 656. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=CT
# (41.544654, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 659. City:CT
# (41.544654, CT, County:Litchfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 661. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 673. City:NEW HARTFORD, CT, County:Litchfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=NEWINGTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 675. City:NEWINGTON, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=MYSTIC, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 676. City:MYSTIC, CT, County:Stonington
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 705. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 707. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=ENFIELD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 712. City:ENFIELD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=DANBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 721. City:DANBURY, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=SHELTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 762. City:SHELTON, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=BRISTOL, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 764. City:BRISTOL, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=NORTH HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 784. City:NORTH HAVEN, CT, County:Wallingford
# https://maps.googleapis.com/maps/api/geocode/json?address=WATERBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 791. City:WATERBURY, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=MANSFIELD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 805. City:MANSFIELD, CT, County:Tolland County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 819. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=MANCHESTER, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 838. City:MANCHESTER, CT, County:Manchester
# https://maps.googleapis.com/maps/api/geocode/json?address=STRATFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 848. City:STRATFORD, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=ASHFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 851. City:ASHFORD, CT, County:Windham County
# https://maps.googleapis.com/maps/api/geocode/json?address=DANBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 855. City:DANBURY, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=CROMWELL, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 864. City:CROMWELL, CT, County:Portland
# https://maps.googleapis.com/maps/api/geocode/json?address=EAST HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 870. City:EAST HARTFORD, CT, County:Manchester
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 895. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=SOUTHINGTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 903. City:SOUTHINGTON, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 905. City:NEW HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=WETHERSFIELD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 916. City:WETHERSFIELD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=BRISTOL, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 972. City:BRISTOL, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=WILLIMANTIC, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 977. City:WILLIMANTIC, CT, County:Windham
# https://maps.googleapis.com/maps/api/geocode/json?address=GROTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 987. City:GROTON, CT, County:Groton
# https://maps.googleapis.com/maps/api/geocode/json?address=EAST HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1016. City:EAST HARTFORD, CT, County:Manchester
# https://maps.googleapis.com/maps/api/geocode/json?address=UNCASVILLE, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1033. City:UNCASVILLE, CT, County:Montville
# https://maps.googleapis.com/maps/api/geocode/json?address=TORRINGTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1034. City:TORRINGTON, CT, County:Litchfield
# https://maps.googleapis.com/maps/api/geocode/json?address=MILFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1046. City:MILFORD, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=PLAINFIELD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1051. City:PLAINFIELD, CT, County:Windham County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1058. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1064. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1078. City:NEW HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1079. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1087. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1108. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=SOUTHINGTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1123. City:SOUTHINGTON, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=WILLIMANTIC, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1153. City:WILLIMANTIC, CT, County:Windham
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1188. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=WATERBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1198. City:WATERBURY, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=CHAPLIN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1200. City:CHAPLIN, CT, County:Windham County
# https://maps.googleapis.com/maps/api/geocode/json?address=WATERBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1210. City:WATERBURY, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=MERIDEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1229. City:MERIDEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1244. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1280. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=ENFIELD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1286. City:ENFIELD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=GREENWICH, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1287. City:GREENWICH, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW MILFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1289. City:NEW MILFORD, CT, County:Litchfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=W HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1299. City:W HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=CHESTER, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1316. City:CHESTER, CT, County:Deep River
# https://maps.googleapis.com/maps/api/geocode/json?address=MARLBOROUGH, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1319. City:MARLBOROUGH, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1350. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=WINDSOR, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1369. City:WINDSOR, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=GUILFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1411. City:GUILFORD, CT, County:Guilford
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1416. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW BRITAIN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1427. City:NEW BRITAIN, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=TORRINGTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1443. City:TORRINGTON, CT, County:Litchfield
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1447. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=BRISTOL, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1449. City:BRISTOL, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=BROOKLYN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1458. City:BROOKLYN, CT, County:Windham County
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1465. City:NEW HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=STAMFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1466. City:STAMFORD, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=STAMFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1474. City:STAMFORD, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=OAKVILLE, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1510. City:OAKVILLE, CT, County:Watertown
# https://maps.googleapis.com/maps/api/geocode/json?address=BROAD BROOK, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1526. City:BROAD BROOK, CT, County:East Windsor
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1532. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1533. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=DANBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1542. City:DANBURY, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=WATERBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1586. City:WATERBURY, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=ENFIELD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1597. City:ENFIELD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=MERIDEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1612. City:MERIDEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=CT
# (41.544654, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1615. City:CT
# (41.544654, CT, County:Litchfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1629. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1633. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=SOUTHINGTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1643. City:SOUTHINGTON, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW LONDON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1646. City:NEW LONDON, CT, County:New London
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1647. City:NEW HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=VERNON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1660. City:VERNON, CT, County:Manchester
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1665. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=WATERBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1694. City:WATERBURY, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1712. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=MERIDEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1717. City:MERIDEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=WATERBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1728. City:WATERBURY, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW BRITAIN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1730. City:NEW BRITAIN, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=MERIDEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1736. City:MERIDEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=CT
# (41.544654, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1748. City:CT
# (41.544654, CT, County:Litchfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=DEEP RIVER, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1756. City:DEEP RIVER, CT, County:Deep River
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1764. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1780. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1798. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=MERIDEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1803. City:MERIDEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=NORWALK, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1819. City:NORWALK, CT, County:Huntington
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1821. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1840. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=NORWICH, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1846. City:NORWICH, CT, County:New London
# https://maps.googleapis.com/maps/api/geocode/json?address=OXFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1879. City:OXFORD, CT, County:Newtown
# https://maps.googleapis.com/maps/api/geocode/json?address=NORWICH, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1885. City:NORWICH, CT, County:New London
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1900. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=TORRINGTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1924. City:TORRINGTON, CT, County:Litchfield
# https://maps.googleapis.com/maps/api/geocode/json?address=DANBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1928. City:DANBURY, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1930. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=DERBY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1965. City:DERBY, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=STERLING, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 1971. City:STERLING, CT, County:Windham County
# https://maps.googleapis.com/maps/api/geocode/json?address=CLINTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2000. City:CLINTON, CT, County:Middlesex County
# https://maps.googleapis.com/maps/api/geocode/json?address=WILLIMANTIC, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2004. City:WILLIMANTIC, CT, County:Windham
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2005. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=JEWETT CITY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2006. City:JEWETT CITY, CT, County:Griswold
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2010. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2011. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=WEST HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2012. City:WEST HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=TERRYVILLE, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2014. City:TERRYVILLE, CT, County:Plymouth
# https://maps.googleapis.com/maps/api/geocode/json?address=BURLINGTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2016. City:BURLINGTON, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2017. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2019. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=WINDSOR, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2020. City:WINDSOR, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=WATERBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2021. City:WATERBURY, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=WALLINGFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2023. City:WALLINGFORD, CT, County:Wallingford
# https://maps.googleapis.com/maps/api/geocode/json?address=SOMERS, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2025. City:SOMERS, CT, County:Tolland County
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2027. City:NEW HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2039. City:NEW HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=ENFIELD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2040. City:ENFIELD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW LONDON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2041. City:NEW LONDON, CT, County:New London
# https://maps.googleapis.com/maps/api/geocode/json?address=MANCHESTER, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2047. City:MANCHESTER, CT, County:Manchester
# https://maps.googleapis.com/maps/api/geocode/json?address=STONINGTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2053. City:STONINGTON, CT, County:Stonington
# https://maps.googleapis.com/maps/api/geocode/json?address=THOMPSON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2054. City:THOMPSON, CT, County:Windham County
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2056. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2057. City:NEW HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW BRITAIN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2058. City:NEW BRITAIN, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=BRANFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2059. City:BRANFORD, CT, County:Guilford
# https://maps.googleapis.com/maps/api/geocode/json?address=WEST HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2063. City:WEST HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=BROOKLYN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2065. City:BROOKLYN, CT, County:Windham County
# https://maps.googleapis.com/maps/api/geocode/json?address=GRISWOLD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2068. City:GRISWOLD, CT, County:New London
# https://maps.googleapis.com/maps/api/geocode/json?address=SOUTHINGTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2073. City:SOUTHINGTON, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=TRUMBULL, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2074. City:TRUMBULL, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2075. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=WATERBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2076. City:WATERBURY, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2083. City:NEW HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=BRANFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2087. City:BRANFORD, CT, County:Guilford
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2090. City:NEW HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=NAUGATUCK, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2091. City:NAUGATUCK, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=TORRINGTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2092. City:TORRINGTON, CT, County:Litchfield
# https://maps.googleapis.com/maps/api/geocode/json?address=DANBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2094. City:DANBURY, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2098. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=WATERBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2100. City:WATERBURY, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=ENFIELD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2101. City:ENFIELD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2105. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=DERBY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2110. City:DERBY, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=MERIDEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2113. City:MERIDEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=WILLIMANTIC, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2115. City:WILLIMANTIC, CT, County:Windham
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW LONDON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2117. City:NEW LONDON, CT, County:New London
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2121. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2123. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=DERBY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2125. City:DERBY, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW BRITAIN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2126. City:NEW BRITAIN, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW BRITAIN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2129. City:NEW BRITAIN, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2130. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=FAIRFIELD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2131. City:FAIRFIELD, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=OAKDALE, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2132. City:OAKDALE, CT, County:Montville
# https://maps.googleapis.com/maps/api/geocode/json?address=SHARON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2133. City:SHARON, CT, County:Litchfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=WOODSTOCK, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2138. City:WOODSTOCK, CT, County:Windham County
# https://maps.googleapis.com/maps/api/geocode/json?address=BRISTOL, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2139. City:BRISTOL, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=BRISTOL, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2141. City:BRISTOL, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=TORRINGTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2144. City:TORRINGTON, CT, County:Litchfield
# https://maps.googleapis.com/maps/api/geocode/json?address=UNCASVILLE, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2145. City:UNCASVILLE, CT, County:Montville
# https://maps.googleapis.com/maps/api/geocode/json?address=LEBANON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2151. City:LEBANON, CT, County:Colchester
# https://maps.googleapis.com/maps/api/geocode/json?address=EAST HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2152. City:EAST HARTFORD, CT, County:Manchester
# https://maps.googleapis.com/maps/api/geocode/json?address=COLCHESTER, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2157. City:COLCHESTER, CT, County:Colchester
# https://maps.googleapis.com/maps/api/geocode/json?address=FRANKLIN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2159. City:FRANKLIN, CT, County:New London
# https://maps.googleapis.com/maps/api/geocode/json?address=WATERBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2160. City:WATERBURY, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=MERIDEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2162. City:MERIDEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=WATERBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2166. City:WATERBURY, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=DANBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2167. City:DANBURY, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=DANBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2168. City:DANBURY, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=WEST HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2170. City:WEST HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW BRITAIN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2171. City:NEW BRITAIN, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2172. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=WATERBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2173. City:WATERBURY, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=NORWICH, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2177. City:NORWICH, CT, County:New London
# https://maps.googleapis.com/maps/api/geocode/json?address=WILLIMANTIC, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2179. City:WILLIMANTIC, CT, County:Windham
# https://maps.googleapis.com/maps/api/geocode/json?address=STRATFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2180. City:STRATFORD, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=WATERBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2185. City:WATERBURY, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW LONDON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2186. City:NEW LONDON, CT, County:New London
# https://maps.googleapis.com/maps/api/geocode/json?address=MERIDEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2187. City:MERIDEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=QUAKER HILL, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2188. City:QUAKER HILL, CT, County:Waterford
# https://maps.googleapis.com/maps/api/geocode/json?address=MIDDLETOWN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2190. City:MIDDLETOWN, CT, County:Middlesex County
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2191. City:NEW HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2192. City:NEW HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=MANCHESTER, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2193. City:MANCHESTER, CT, County:Manchester
# https://maps.googleapis.com/maps/api/geocode/json?address=DERBY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2196. City:DERBY, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=WESTBROOK, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2197. City:WESTBROOK, CT, County:Westbrook
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2199. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2203. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2205. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=GROTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2210. City:GROTON, CT, County:Groton
# https://maps.googleapis.com/maps/api/geocode/json?address=BRISTOL, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2211. City:BRISTOL, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=MANCHESTER, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2213. City:MANCHESTER, CT, County:Manchester
# https://maps.googleapis.com/maps/api/geocode/json?address=DAYVILLE, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2214. City:DAYVILLE, CT, County:Killingly
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2215. City:NEW HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2217. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2218. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=UNCASVILLE, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2221. City:UNCASVILLE, CT, County:Montville
# https://maps.googleapis.com/maps/api/geocode/json?address=BRISTOL, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2223. City:BRISTOL, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=MONROE, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2224. City:MONROE, CT, County:Newtown
# ...
# Empty county found at 2912. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=FAIRFIELD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2914. City:FAIRFIELD, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=WEST HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2917. City:WEST HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=WEST HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2919. City:WEST HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=DANBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2925. City:DANBURY, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=DERBY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2931. City:DERBY, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2932. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2933. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW CANAAN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2935. City:NEW CANAAN, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=CROMWELL, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2936. City:CROMWELL, CT, County:Portland
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW BRITAIN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2939. City:NEW BRITAIN, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2940. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=MERIDEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2941. City:MERIDEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=WEST HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2943. City:WEST HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=ENFIELD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2946. City:ENFIELD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=HEBRON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2947. City:HEBRON, CT, County:Colchester
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2950. City:NEW HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2955. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2959. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=WEST HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2964. City:WEST HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2965. City:NEW HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=WATERFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2967. City:WATERFORD, CT, County:Waterford
# https://maps.googleapis.com/maps/api/geocode/json?address=GROTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2968. City:GROTON, CT, County:Groton
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2972. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=WATERBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2975. City:WATERBURY, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2978. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2981. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2986. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=ANSONIA, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2989. City:ANSONIA, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=SOUTHINGTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2994. City:SOUTHINGTON, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2996. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 2999. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=PROSPECT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3000. City:PROSPECT, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3001. City:NEW HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=SHELTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3002. City:SHELTON, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=TORRINGTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3003. City:TORRINGTON, CT, County:Litchfield
# https://maps.googleapis.com/maps/api/geocode/json?address=NORWALK, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3004. City:NORWALK, CT, County:Huntington
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3005. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=STRATFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3006. City:STRATFORD, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=LEBANON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3007. City:LEBANON, CT, County:Colchester
# https://maps.googleapis.com/maps/api/geocode/json?address=DANBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3008. City:DANBURY, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=COLCHESTER, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3009. City:COLCHESTER, CT, County:Colchester
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3011. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=MERIDEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3012. City:MERIDEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=STAMFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3013. City:STAMFORD, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=WETHERSFIELD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3014. City:WETHERSFIELD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=BRISTOL, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3015. City:BRISTOL, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=ORANGE, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3016. City:ORANGE, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=SOUTHINGTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3017. City:SOUTHINGTON, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=KILLINGLY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3018. City:KILLINGLY, CT, County:Windham County
# https://maps.googleapis.com/maps/api/geocode/json?address=WOODSTOCK, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3019. City:WOODSTOCK, CT, County:Windham County
# https://maps.googleapis.com/maps/api/geocode/json?address=SHELTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3020. City:SHELTON, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW BRITAIN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3021. City:NEW BRITAIN, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3022. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3023. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=ANSONIA, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3025. City:ANSONIA, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3026. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3027. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=WEST HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3029. City:WEST HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=WALLINGFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3030. City:WALLINGFORD, CT, County:Wallingford
# https://maps.googleapis.com/maps/api/geocode/json?address=BRIDGEPORT, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3031. City:BRIDGEPORT, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3032. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=WINDSOR LOCKS, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3033. City:WINDSOR LOCKS, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW LONDON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3034. City:NEW LONDON, CT, County:New London
# https://maps.googleapis.com/maps/api/geocode/json?address=MIDDLETOWN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3035. City:MIDDLETOWN, CT, County:Middlesex County
# https://maps.googleapis.com/maps/api/geocode/json?address=NEW HAVEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3036. City:NEW HAVEN, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=NORWALK, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3037. City:NORWALK, CT, County:Huntington
# https://maps.googleapis.com/maps/api/geocode/json?address=WEST HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3038. City:WEST HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=HAMDEN, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3039. City:HAMDEN, CT, County:Wallingford
# https://maps.googleapis.com/maps/api/geocode/json?address=WATERBURY, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3040. City:WATERBURY, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=WEST SUFFIELD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3041. City:WEST SUFFIELD, CT, County:Suffield
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3042. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=SHELTON, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3043. City:SHELTON, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=HARTFORD, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3044. City:HARTFORD, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=East Haven, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3051. City:East Haven, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=Hartford, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3126. City:Hartford, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=Stratford, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3222. City:Stratford, CT, County:Fairfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=Enfield, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3271. City:Enfield, CT, County:Hartford County
# https://maps.googleapis.com/maps/api/geocode/json?address=Ashford, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3352. City:Ashford, CT, County:Windham County
# https://maps.googleapis.com/maps/api/geocode/json?address=South Windsor, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3396. City:South Windsor, CT, County:Manchester
# https://maps.googleapis.com/maps/api/geocode/json?address=Groton, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3467. City:Groton, CT, County:Groton
# https://maps.googleapis.com/maps/api/geocode/json?address=New Haven, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3476. City:New Haven, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=Watertown, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3507. City:Watertown, CT, County:Litchfield County
# https://maps.googleapis.com/maps/api/geocode/json?address=Plainfield, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3615. City:Plainfield, CT, County:Windham County
# https://maps.googleapis.com/maps/api/geocode/json?address=Naugatuck, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3656. City:Naugatuck, CT, County:New Haven
# https://maps.googleapis.com/maps/api/geocode/json?address=Plainfield, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3681. City:Plainfield, CT, County:Windham County
# https://maps.googleapis.com/maps/api/geocode/json?address=6340, CT&key=AIzaSyBjsj3aFg-MyGnQQuWSRgRENqwNK6wXgwo
# Empty county found at 3798. City:6340, CT, County:Connecticut Avenue

# %% [markdown]
# ### Clean the county names

# %%
drug_death_raw_df['Death County'].value_counts()
# Out:
# HARTFORD              1022
# NEW HAVEN              975
# FAIRFIELD              555
# NEW LONDON             319
# LITCHFIELD             187
# Hartford County        181
# MIDDLESEX              154
# New Haven              140
# WINDHAM                116
# TOLLAND                100
# Fairfield County        99
# New London              37
# Manchester              29
# Windham County          23
# Litchfield              16
# Wallingford             15
# Tolland County          14
# Litchfield County       11
# Windham                 10
# Middlesex County        10
# Huntington               8
# Colchester               7
# Portland                 6
# Groton                   6
# Deep River               4
# Guilford                 4
# Montville                4
# Stonington               3
# Waterford                3
# Killingly                2
# Bethel                   2
# East Windsor             2
# Newtown                  2
# Simsbury                 2
# Winchester               1
# Westbrook                1
# Greenwich                1
# Sprague                  1
# Suffield                 1
# Connecticut Avenue       1
# Haddam                   1
# Plymouth                 1
# Watertown                1
# Griswold                 1
# Madison                  1
# USA                      1
# Mansfield                1
#  FAIRFIELD               1
# Name: Death County, dtype: int64

# %%
# County names in uppercase
drug_death_raw_df['Death County'] = drug_death_raw_df['Death County'].str.upper()
# Remove 'County' from the county names
remove_county = lambda x: ' '.join(x.split(' ')[:-1]) if 'COUNTY' in x else x
drug_death_raw_df['Death County'] = drug_death_raw_df['Death County'].apply(remove_county)
# Remove whitespace
drug_death_raw_df['Death County'] = drug_death_raw_df['Death County'].str.strip()
# Clean the county cells filled with city names
cities = {'MANCHESTER':'HARTFORD', 'WALLINGFORD':'NEW HAVEN',
         'HUNTINGTON':'FAIRFIELD','COLCHESTER':'NEW LONDON',
         'PORTLAND':'MIDDLESEX', 'GROTON':'NEW LONDON',
         'GUILFORD':'NEW HAVEN', 'MONTVILLE':'NEW LONDON',
         'DEEP RIVER':'MIDDLESEX','STONINGTON':'NEW LONDON',
         'WATERFORD':'NEW LONDON','KILLINGLY':'WINDHAM',
         'SIMSBURY':'HARTFORD', 'EAST WINDSOR':'HARTFORD',
         'NEWTOWN':'FAIRFIELD', 'BETHEL':'FAIRFIELD',
         'WESTBROOK':'MIDDLESEX','HADDAM':'MIDDLESEX',
         'WINCHESTER':'LITCHFIELD','SPRAGUE':'NEW LONDON',
         'GREENWICH':'FAIRFIELD','MADISON':'NEW HAVEN',
         'WATERTOWN':'LITCHFIELD','GRISWOLD':'NEW LONDON',
         'PLYMOUTH':'LITCHFIELD','MANSFIELD':'TOLLAND',
         'CONNECTICUT AVENUE':'HARTFORD', 'SUFFIELD':'HARTFORD'}
replace_cities = lambda x: cities.get(x) if x in cities.keys() else x
drug_death_raw_df['Death County']= drug_death_raw_df['Death County'].apply(replace_cities)

# %%
drug_death_df = drug_death_raw_df[drug_death_raw_df['Death County'] != 'USA']

# %%
drug_death_df['Death County']
